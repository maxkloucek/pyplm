# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import h5py
import networkx as nx
# plt.style.use("/Users/mk14423/Dropbox/custom.mplstyle")

# %%
# file = 'testdata/test3.hdf5'
# group = 'simtest'
# file = 'testdata/test1.hdf5'
# group = 'simtest'
file = 'testdata/test1.hdf5'
group = 'simtest3'

with h5py.File(file, 'r') as fin:
    in_models = fin[group + '/inputModels'][()]
    out_models = fin[group + '/inferredModels'][()]
    trajectories = fin[group + '/configurations'][()]

    mod_md = fin[group + '/inputModels_metadata'].asstr()[()]
    sim_md = fin[group + '/configurations_metadata'].asstr()[()]
    inf_md = fin[group + '/inferredModels_metadata'].asstr()[()]
    print(mod_md)
    print(sim_md)
    print(inf_md)
    print(in_models.shape)
# Out:
# ["{'model': 'SK', 'N': 64, 'T': 0.6, 'h': 0, 'jmean': 0.4, 'jstd': 1}"]
# ["{'B_eq': 1000.0, 'B_sample': 5000.0, 'nChains': 6}"]
# ['3']
# (1, 64, 64)

# %%
h_ins = []
h_outs = []
for i in range(0, 1):
    in_mod = in_models[i]
    out_mod = out_models[i]
    h_in = np.mean(in_mod.diagonal())
    h_out = np.mean(out_mod.diagonal())
    h_ins.append(h_in)
    h_outs.append(h_out)

h_ins = np.array(h_ins)
h_outs = np.array(h_outs)
h_err = np.abs(h_outs-h_ins)
plt.plot(h_ins, h_err)
plt.show()

# %%
i_boys = [0, 10, 25, 50]
for i in i_boys:
    in_mod = in_models[i][0:10, 0:10]
    out_mod = out_models[i][0:10, 0:10]
    trajectory = trajectories[i][0:10, 0:10]
    dataCov = np.cov(trajectory.T)
    N, _ = in_mod.shape

    in_params = in_mod[np.triu_indices(N, k=0)]
    out_params = out_mod[np.triu_indices(N, k=0)]
    dataCov_flat = dataCov[np.triu_indices(N, k=0)]
    print(i, N, in_params.shape)
    fig, ax = plt.subplots(1, 3, figsize=(9.5, 5))
    ax = ax.ravel()
    nbins=250
#     ax[0].hist(in_params, bins=nbins, density=True)
#     ax[0].hist(out_params, bins=nbins, density=True)
#     ax.hist(dataCov_flat, bins=bins, density=True)
    ax[0].imshow(dataCov)
    ax[1].imshow(in_mod)
    ax[2].imshow(out_mod)
    plt.show()
#     fig, ax = plt.subplots(1, 3, figsize=(9.9, 5))
#     ax = ax.ravel()
#     
#     ax[2].imshow(np.cov(trajectories[i].T))
#     plt.show()
# Out:
# 0 10 (55,)
# <img src="data:image/png;base64,..." width="950">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/k5/bpv6mcg170d8jp0sx5q8rk_00000gq/T/ipykernel_56304/1685583981.py in <module>
#       1 i_boys = [0, 10, 25, 50]
#       2 for i in i_boys:
# ----> 3     in_mod = in_models[i][0:10, 0:10]
#       4     out_mod = out_models[i][0:10, 0:10]
#       5     trajectory = trajectories[i][0:10, 0:10]
#
# IndexError: index 10 is out of bounds for axis 0 with size 1

# %%
Cij = np.cov(full_traj.T)
vmin = 1e-3
Cij[Cij <= vmin] = vmin
Cr, r = collapseRadially_periodic(Cij)
Jr, r = collapseRadially_periodic(Jij)

fig, ax = plt.subplots(2, 2)
norm = LogNorm(Cij.min(), Cij.max())
ax[0, 0].imshow(Cij[0:100, 0:100], norm=norm)
ax[0, 1].imshow(Jij[0:100, 0:100])

ax[1, 0].plot(r, Cr)
ax[1, 0].set(ylim=[vmin, None], yscale='log')
ax[1, 1].plot(r, Jr)
plt.show()

Jij[Jij <= 1e-2] = 0
J = nx.from_numpy_array(Jij)

Cij[Cij <= 1e-2] = 0
np.fill_diagonal(Cij, 0)
C = nx.from_numpy_array(Cij)

fig, ax = plt.subplots(1, 2)
ax = ax.ravel()

pos = nx.circular_layout(J)
nx.draw(J, pos=pos, ax=ax[0])

pos = nx.circular_layout(C)
nx.draw(C, pos=pos, ax=ax[1])
plt.show()

# nx.write_graphml(J, './J.graphml')
# nx.write_graphml(C, './C.graphml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/k5/bpv6mcg170d8jp0sx5q8rk_00000gq/T/ipykernel_56304/903482054.py in <module>
# ----> 1 Cij = np.cov(full_traj.T)
#       2 vmin = 1e-3
#       3 Cij[Cij <= vmin] = vmin
#       4 Cr, r = collapseRadially_periodic(Cij)
#       5 Jr, r = collapseRadially_periodic(Jij)
#
# NameError: name 'full_traj' is not defined
